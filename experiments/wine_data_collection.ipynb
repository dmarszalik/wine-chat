# %%
import pandas as pd
import os

import ast

from tqdm.notebook import tqdm

# %%
# Path to folder with JSON files
folder_path = '/content/drive/MyDrive/datasets/wines'

progress_bar = tqdm(os.listdir(folder_path), desc="Processing files", leave=True)

# Initialize an empty list to store DataFrames
dataframes = []

# Go through the files in the folder and load them into the DataFrame
for file in os.listdir(folder_path):
    if file.endswith('.json'):
        file_path = os.path.join(folder_path, file)
        try:
            df = pd.read_json(file_path)
            dataframes.append(df)
        except Exception as e:
            print(f"File loading error {file}: {e}")

# Combine all DataFrames into one
merged_dataframe = pd.concat(dataframes, ignore_index=True)

# Save to CSV
csv_filename = '/content/drive/MyDrive/datasets/merged_wine_data.csv'
merged_dataframe.to_csv(csv_filename, index=False)

print(f"Successfully merged and saved in {csv_filename}")
# Out:
# Processing files:   0%|          | 0/1073 [00:00<?, ?it/s]
# Successfully merged and saved in /content/drive/MyDrive/datasets/merged_wine_data.csv

# %%
dataframe = pd.read_csv('/content/drive/MyDrive/datasets/merged_wine_data.csv')

# %%
dataframe.head
# Out:
# <bound method NDFrame.head of                                                    wines
# 0      {'name': 'Moscato', 'price': {'id': 33340883, ...
# 1      {'name': 'Indisciplinato', 'price': {'id': 309...
# 2      {'name': 'Reserve Collection Pinot Noir', 'pri...
# 3      {'name': "Stokes' Ghost Petite Sirah", 'price'...
# 4      {'name': 'Défier Coquelicot Vineyard Merlot', ...
# ...                                                  ...
# 26820  {'name': 'Bloom & Bramble Chardonnay', 'price'...
# 26821  {'name': 'Royal Seyssel Grand Cru Régional', '...
# 26822  {'name': 'Grande Reserve Côtes de Bourg Rouge'...
# 26823  {'name': 'Argenina Gran Selezione Chianti Clas...
# 26824  {'name': 'Private Reserve Pinot Noir', 'price'...
#
# [26825 rows x 1 columns]>

# %%
dataframe.iloc[11]['wines']
# Out:
# "{'name': 'Merlot', 'price': {'id': 28440603, 'merchant_id': 31839, 'amount': 29.99, 'discounted_from': None, 'discount_percent': None, 'type': 'vc', 'sku': '63574', 'url': 'https://www.classycorksdc.com/wines/Starmont-Winery-Merlot-2018-w4314924v2?utm_source=Vivino&utm_medium=Feed', 'visibility': 1, 'bottle_type_id': 1, 'currency': {'code': 'USD', 'name': 'US Dollars', 'prefix': '$', 'suffix': None}, 'bottle_type': {'id': 1, 'name': 'Bottle (0.75l)', 'short_name': 'bottle', 'short_name_plural': 'bottles', 'volume_ml': 750}}, 'taste': {'structure': {'acidity': 1.857961, 'fizziness': None, 'intensity': 3.9818263, 'sweetness': 1.9654433, 'tannin': 2.1349912, 'user_structure_count': 16, 'calculated_structure_count': 121}, 'flavor': [{'group': 'oak', 'stats': {'count': 79, 'score': 12550, 'mentions_count': 139}, 'primary_keywords': [{'id': 292, 'name': 'oak', 'count': 39}, {'id': 434, 'name': 'vanilla', 'count': 38}, {'id': 101, 'name': 'chocolate', 'count': 16}, {'id': 422, 'name': 'tobacco', 'count': 15}, {'id': 83, 'name': 'cedar', 'count': 12}, {'id': 117, 'name': 'coffee', 'count': 4}, {'id': 21, 'name': 'baking spice', 'count': 4}, {'id': 112, 'name': 'clove', 'count': 3}, {'id': 134, 'name': 'dark chocolate', 'count': 3}, {'id': 79, 'name': 'caramel', 'count': 1}, {'id': 138, 'name': 'dill', 'count': 1}, {'id': 275, 'name': 'milk chocolate', 'count': 1}, {'id': 115, 'name': 'coconut', 'count': 1}, {'id': 308, 'name': 'pastry', 'count': 1}], 'secondary_keywords': [{'id': 242, 'name': 'leather', 'count': 8}, {'id': 384, 'name': 'smoke', 'count': 5}, {'id': 65, 'name': 'brown sugar', 'count': 1}, {'id': 81, 'name': 'carob', 'count': 1}]}, {'group': 'black_fruit', 'stats': {'count': 66, 'score': 9943, 'mentions_count': 100}, 'primary_keywords': [{'id': 334, 'name': 'plum', 'count': 33}, {'id': 49, 'name': 'blackberry', 'count': 24}, {'id': 55, 'name': 'blueberry', 'count': 12}, {'id': 470, 'name': 'cassis', 'count': 7}, {'id': 135, 'name': 'dark fruit', 'count': 6}, {'id': 52, 'name': 'blackcurrant', 'count': 6}, {'id': 43, 'name': 'black plum', 'count': 4}, {'id': 39, 'name': 'black fruit', 'count': 3}, {'id': 229, 'name': 'jam', 'count': 2}, {'id': 38, 'name': 'black cherry', 'count': 2}, {'id': 57, 'name': 'bramble', 'count': 1}], 'secondary_keywords': [{'id': 341, 'name': 'prune', 'count': 3}]}, {'group': 'red_fruit', 'stats': {'count': 44, 'score': 5198, 'mentions_count': 51}, 'primary_keywords': [{'id': 93, 'name': 'cherry', 'count': 23}, {'id': 348, 'name': 'raspberry', 'count': 12}, {'id': 354, 'name': 'red fruit', 'count': 7}, {'id': 400, 'name': 'strawberry', 'count': 5}, {'id': 122, 'name': 'cranberry', 'count': 2}, {'id': 353, 'name': 'red currant', 'count': 1}, {'id': 357, 'name': 'red plum', 'count': 1}], 'secondary_keywords': [{'id': 229, 'name': 'jam', 'count': 2}, {'id': 38, 'name': 'black cherry', 'count': 2}, {'id': 176, 'name': 'fruitcake', 'count': 2}]}, {'group': 'earth', 'stats': {'count': 32, 'score': 2988, 'mentions_count': 28}, 'primary_keywords': [{'id': 242, 'name': 'leather', 'count': 8}, {'id': 384, 'name': 'smoke', 'count': 5}, {'id': 156, 'name': 'earthy', 'count': 3}, {'id': 178, 'name': 'game', 'count': 2}, {'id': 284, 'name': 'mushroom', 'count': 1}, {'id': 276, 'name': 'minerals', 'count': 1}, {'id': 192, 'name': 'graphite', 'count': 1}, {'id': 226, 'name': 'iron', 'count': 1}, {'id': 207, 'name': 'grilled meat', 'count': 1}, {'id': 466, 'name': 'plastic', 'count': 1}, {'id': 430, 'name': 'truffle', 'count': 1}, {'id': 318, 'name': 'pencil shavings', 'count': 1}, {'id': 22, 'name': 'balsamic', 'count': 1}, {'id': 412, 'name': 'tar', 'count': 1}], 'secondary_keywords': [{'id': 422, 'name': 'tobacco', 'count': 15}, {'id': 134, 'name': 'dark chocolate', 'count': 3}, {'id': 350, 'name': 'red beet', 'count': 1}]}, {'group': 'spices', 'stats': {'count': 52, 'score': 2107, 'mentions_count': 18}, 'primary_keywords': [{'id': 320, 'name': 'pepper', 'count': 10}, {'id': 277, 'name': 'mint', 'count': 4}, ...

# %%
data_dict = ast.literal_eval(dataframe['wines'][0])
reviews = data_dict['reviews']

# %%
len(reviews)
# Out:
# 3

# %%
reviews[0]['note']
# Out:
# 'Wow I was incredibly taken back by this moscato. Light yet has notes of white peach & lychee with the mid pallet some  minerals truly lovely and a perfect sweet balance not too sweet not to light. '

# %%
data_list = []

for i in range(dataframe.shape[0]):
    data_dict = ast.literal_eval(dataframe['wines'][i])
    selected_data = {}
    selected_data['style_name'] = data_dict['name']
    selected_data['price'] = data_dict['price']['amount']
    selected_data['currency'] = data_dict['price']['currency']['code']
    selected_data['volume'] = data_dict['price']['bottle_type']['volume_ml']

    if data_dict['taste'] is not None and data_dict['taste']['structure'] is not None:
        selected_data['acidity'] = data_dict['taste']['structure'].get('acidity', None)
        selected_data['fizziness'] = data_dict['taste']['structure'].get('fizziness', None)
        selected_data['sweetness'] = data_dict['taste']['structure'].get('sweetness', None)
        selected_data['tannin'] = data_dict['taste']['structure'].get('tannin', None)
        selected_data['user_structure_count'] = data_dict['taste']['structure'].get('user_structure_count', None)
        selected_data['calculated_structure_count'] = data_dict['taste']['structure'].get('calculated_structure_count', None)


    reviews = data_dict['reviews']
    vintages = [reviews[i]['vintage'] for i in range(len(reviews))]
    notes = [reviews[i]['note'] for i in range(len(reviews))]
    selected_data['wine_name'] = vintages[0]['name']
    region = vintages[0]['wine']['region']
    selected_data['rating'] = reviews[0]['rating']
    selected_data['region_name'] = region['name']
    selected_data['country'] = region['country']['name']
    selected_data['winery'] = vintages[0]['wine']['winery']['name']
    selected_data['image'] = vintages[0]['image']['location']

    sequence_tokens = ['SEP'] + notes + ['SEP']
    selected_data['combined_reviews'] = ' '.join('SEP ' + str(note) for note in notes)

    selected_data['flavours'] = []
    for review in reviews:
        flavor_matches = review.get('flavor_word_matches')
        if flavor_matches is not None:
            selected_data['flavours'].extend(match.get('match') for match in flavor_matches)



    data_list.append(selected_data)

df = pd.DataFrame(data_list)

# %%
df.head()
# Out:
#                           style_name      price currency  volume   acidity  \
# 0                            Moscato  12.990000      USD     750  3.067054
# 1                     Indisciplinato  27.990000      USD     750  3.442514
# 2      Reserve Collection Pinot Noir  24.990000      USD     750  3.870318
# 3         Stokes' Ghost Petite Sirah  29.916667      USD     750  3.413706
# 4  Défier Coquelicot Vineyard Merlot  29.990000      USD     750  1.827581
#
#    fizziness  sweetness    tannin  user_structure_count  \
# 0        NaN   3.271635       NaN                  18.0
# 1        NaN   1.623086       NaN                   9.0
# 2        NaN   1.416349  1.883968                   1.0
# 3        NaN   1.921906  4.333656                  22.0
# 4        NaN   1.946129  2.162903                   2.0
#
#    calculated_structure_count  \
# 0                       192.0
# 1                         1.0
# 2                         3.0
# 3                       145.0
# 4                        11.0
#
#                                           wine_name  rating  \
# 0                      Seven Daughters Moscato U.V.     4.1
# 1           Tenuta San Marcello Indisciplinato U.V.     2.5
# 2          Erath Reserve Collection Pinot Noir 2019     4.2
# 3  Scheid Vineyards Stokes' Ghost Petite Sirah U.V.     4.1
# 4     J.Brix Défier Coquelicot Vineyard Merlot U.V.     4.1
#
#          region_name        country               winery  \
# 0             Veneto          Italy      Seven Daughters
# 1             Marche          Italy  Tenuta San Marcello
# 2  Willamette Valley  United States                Erath
# 3           Monterey  United States     Scheid Vineyards
# 4  Santa Ynez Valley  United States               J.Brix
#
#                                                image  \
# 0  //images.vivino.com/thumbs/mE6S9dUrSUOFI8qTodT...
# 1  //images.vivino.com/labels/kJVZn2JsRiiUc7Xfz7x...
# 2  //images.vivino.com/labels/DU6Kr8eeTGSC9Cl-5MV...
# 3  //images.vivino.com/thumbs/VhNssH95RtKFPe73dxK...
# 4  //images.vivino.com/thumbs/DWwwq3AtSdWLB_SrbxY...
#
#                                     combined_reviews  \
# 0  SEP Wow I was incredibly taken back by this mo...
# 1  SEP Anfora verdicchio, not satisfied, for the ...
# 2  SEP Excellent expression of Willamette valley!...
# 3  SEP Wowee- great story, great wine. A two-fer!...
# 4  SEP Surprisingly green despite being carbonic....
#
#                                        flavours
# 0  [lychee, minerals, white peach, apple, pear]
# 1                         [dried mango, orange]
# 2                                            []
# 3                                            []
# 4              [black fruit, black olive, plum]

# %%
df['combined_reviews'][1]
# Out:
# 'SEP Anfora verdicchio, not satisfied, for the price especially, a lot of vinegard smell and not much more, after a while peach and flower but I have to say, looks like a farmer wine, good farmer wine but very rude. I had the feeling that natural here is an excuse. Totally unbalanced, not interesting and very rough. Try it again for me is a no a big no especially for 24.5 euro. Absolutely not.  SEP Dried mango, balanced and clean, organic and biodynamic wine producer - tasty\n SEP Very good orange wine, unfiltered and dry on the tongue with a strong aftertaste'

# %%
df.info()

# %%
df.describe()

# %%
df.to_csv('/content/drive/MyDrive/datasets/wines_processed/wines.csv', index=False)
